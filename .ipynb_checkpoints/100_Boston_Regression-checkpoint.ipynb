# %% [markdown]
# # 100. Boston House Price Regression
#
# - 보스턴 주택가격 예측
#
# ### 13 개의 종속변수와 1 개의 독립변수 (주택가격 중앙값) 으로 구성
#
# #### 종속변수 (13 개)
# CRIM 자치시(town) 별 1인당 범죄율
# ZN 25,000 평방피트를 초과하는 거주지역의 비율
# INDUS 비소매상업지역이 점유하고 있는 토지의 비율
# CHAS 찰스강에 대한 더미변수(강의 경계에 위치한 경우는 1, 아니면 0)
# NOX 10ppm 당 농축 일산화질소
# RM 주택 1가구당 평균 방의 개수
# AGE 1940년 이전에 건축된 소유주택의 비율
# DIS 5개의 보스턴 직업센터까지의 접근성 지수
# RAD 방사형 도로까지의 접근성 지수
# TAX 10,000 달러 당 재산세율
# PTRATIO 자치시(town)별 학생/교사 비율
# B 1000(Bk-0.63)^2, 여기서 Bk는 자치시별 흑인의 비율을 말함
# LSTAT 모집단의 하위계층의 비율(%)
#
# #### 독립변수 (1 개)
# MEDV 본인 소유의 주택가격(중앙값) (단위: $1,000)

# %% [markdown]
# 필요한 라이브러리를 import 합니다. TensorFlow/Keras를 사용하여 신경망 모델을 구축하고, sklearn을 사용하여 데이터 전처리와 평가를 수행합니다.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np

# %% [markdown]
# Boston 주택가격 데이터셋을 로드합니다. sklearn의 load_boston이 제거되었으므로 직접 데이터를 다운로드하고 전처리합니다.

# %%
# Boston 데이터셋 직접 로드 (load_boston은 sklearn 1.2+에서 제거됨)
data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep=r"\s+", skiprows=22, header=None)
data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]

feature_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM',
                 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']
df_boston = pd.DataFrame(data, columns=feature_names)
df_boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %% [markdown]
# 특성 데이터(X)와 타겟 데이터(y)를 분리합니다. X는 13개의 특성, y는 주택가격 중앙값입니다.

# %%
X = data
y = target

# %% [markdown]
# 타겟 변수의 처음 10개 값을 확인합니다. 주택가격 중앙값을 확인할 수 있습니다.

# %%
y[:10]
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9])

# %% [markdown]
# 데이터의 형태를 확인합니다. X는 (샘플 수, 특성 수), y는 (샘플 수,) 형태입니다.

# %%
print(X.shape)
print(y.shape)
# Out:
# (506, 13)
# (506,)

# %% [markdown]
# 데이터를 훈련 세트와 테스트 세트로 분할합니다. 기본적으로 75%는 훈련, 25%는 테스트 데이터로 나뉩니다.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((379, 13), (127, 13), (379,), (127,))

# %% [markdown]
# 특성 스케일링을 수행합니다. MinMaxScaler를 사용하여 모든 특성을 0과 1 사이의 값으로 정규화합니다. 신경망 모델의 학습 안정성을 높입니다.

# %%
sc = MinMaxScaler()
X_train = sc.fit_transform(X_train)
X_test  = sc.transform(X_test)

# %% [markdown]
# ### model build

# %% [markdown]
# Sequential 모델을 생성하고 레이어를 추가합니다. 입력층(13개 특성), 은닉층 2개(64, 32 뉴런), 출력층(1개 뉴런)으로 구성된 신경망을 만듭니다.

# %%
model = Sequential([
    Input(shape=(13,)),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1)
])

# %% [markdown]
# 모델을 컴파일합니다. 회귀 문제이므로 손실 함수는 mean_squared_error를 사용하고, 옵티마이저는 adam을 사용합니다.

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %% [markdown]
# 모델의 구조를 요약하여 출력합니다. 각 레이어의 파라미터 수와 모델의 전체 구조를 확인할 수 있습니다.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 64)             │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,009 (11.75 KB)
#  Trainable params: 3,009 (11.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# - epoch 수와 batchz_size 변경하며 test

# %% [markdown]
# 모델을 학습시킵니다. batch_size=32, epochs=100 으로 설정하고, validation_data로 테스트 데이터를 사용하여 검증 손실을 모니터링합니다.

# %%
history = model.fit(X_train, y_train, batch_size=32,
                    epochs=100, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 610.3966 - val_loss: 516.1123
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 567.3984 - val_loss: 488.9959
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 586.7484 - val_loss: 441.9901
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 501.1505 - val_loss: 373.9248
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 414.5164 - val_loss: 284.7421
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 294.0935 - val_loss: 194.6343
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 221.1997 - val_loss: 137.6506
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 149.0237 - val_loss: 124.5689
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 132.1924 - val_loss: 117.0730
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 117.4470 - val_loss: 103.7000
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 122.1140 - val_loss: 92.8482
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 93.8749 - val_loss: 83.9073
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 83.4301 - val_loss: 76.6379
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 94.9198 - val_loss: 70.8609
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 77.2329 - val_loss: 65.2202
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 79.8895 - val_loss: 60.8199
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 62.5634 - val_loss: 57.7919
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 55.5083 - val_loss: 55.3144
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 53.1812 - val_loss: 53.3991
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 60.9604 - val_loss: 51.4752
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 54.5458 - val_loss: 50.0522
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 46.3318 - val_loss: 48.6741
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 45.6362 - val_loss: 47.3604
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 40.4424 - val_loss: 45.9736
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 45.4376 - val_loss: 44.8195
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 46.0674 - val_loss: 43.3934
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 39.1289 - val_loss: 42.0333
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 40.0318 - val_loss: 40.9646
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 41.4359 - val_loss: 39.7522
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 39.0831 - val_loss: 38.5138
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 31.6023 - val_loss: 37.3632
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 34.7841 - val_loss: 36.2561
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 37.2587 - val_loss: 35.3220
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 24.7544 - val_loss: 34.4949
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 25.4919 - val_loss: 33.5399
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 30.7560 - val_loss: 32.6290
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 28.7758 - val_loss: 31.7894
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 22.4443 - val_loss: 31.1002
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 24.3745 - val_loss: 30.3941
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 20.8712 - val_loss: 29.8629
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 20.1297 - val_loss: 29.2313
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 25.7219 - val_loss: 28.7859
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 23.4471 - val_loss: 28.3166
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 22.9412 - val_loss: 28.2403
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 19.6982 - val_loss: 27.4954
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 28.4058 - val_loss: 27.2684
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 25.1067 - val_loss: 26.7410
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 23.9968 - val_loss: 26.5648
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.5830 - val_loss: 26.2940
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.1955 - val_loss: 26.1430
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 18.4376 - val_loss: 25.9018
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.8216 - val_loss: 25.4952
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.3082 - val_loss: 25.4198
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.4248 - val_loss: 25.1751
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.8291 - val_loss: 24.9847
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 18.2154 - val_loss: 24.7624
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 21.0590 - val_loss: 24.6344
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19.5914 - val_loss: 24.4592
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 19.1075 - val_loss: 24.3514
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 15.9448 - val_loss: 24.7425
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19.1525 - val_loss: 24.3758
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.8003 - val_loss: 24.0207
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19.7431 - val_loss: 23.7739
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 16.9985 - val_loss: 23.7232
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.5470 - val_loss: 23.4552
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 17.7309 - val_loss: 23.4360
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19.7059 - val_loss: 23.2753
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.2065 - val_loss: 23.0998
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.2095 - val_loss: 22.9957
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.9403 - val_loss: 23.0830
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.5535 - val_loss: 22.9211
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.4141 - val_loss: 22.7361
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 16.7512 - val_loss: 22.6385
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13.0718 - val_loss: 22.5118
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.5253 - val_loss: 22.5166
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 16.5277 - val_loss: 22.3701
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 16.0566 - val_loss: 22.1904
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.7474 - val_loss: 22.1648
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.0156 - val_loss: 21.8781
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.2032 - val_loss: 21.9709
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.2106 - val_loss: 21.8755
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.6300 - val_loss: 21.7733
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.9063 - val_loss: 21.6375
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.9054 - val_loss: 21.6297
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.9188 - val_loss: 21.3973
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 16.2655 - val_loss: 21.4084
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.9958 - val_loss: 21.4903
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 16.1604 - val_loss: 21.2376
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 17.2187 - val_loss: 21.1564
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 16.4472 - val_loss: 21.1861
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.9899 - val_loss: 21.1654
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.2855 - val_loss: 20.9006
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.0661 - val_loss: 20.7901
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.2216 - val_loss: 20.7801
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13.3936 - val_loss: 20.8448
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 20.1509 - val_loss: 20.6191
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.0870 - val_loss: 20.6498
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 15.6705 - val_loss: 20.7946
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.1222 - val_loss: 20.6845
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.9169 - val_loss: 20.5247

# %% [markdown]
# 학습된 모델을 테스트 데이터로 평가합니다. 테스트 손실 값을 확인할 수 있습니다.

# %%
model.evaluate(X_test, y_test, verbose=0)
# Out:
# 20.524673461914062

# %% [markdown]
# 학습된 모델을 사용하여 테스트 데이터에 대한 예측을 수행합니다.

# %%
y_pred = model.predict(X_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step

# %% [markdown]
# 모델의 성능을 평가합니다. Mean Squared Error(MSE)와 R² 점수를 계산하여 모델의 예측 정확도를 확인합니다.

# %%
from sklearn.metrics import mean_squared_error, r2_score

print(mean_squared_error(y_test, y_pred))
print(r2_score(y_test, y_pred))
# Out:
# 20.524672103367188
# 0.7484691856769503

# %% [markdown]
# 예측 결과를 시각화합니다. 실제값(y_test)과 예측값(y_pred)을 산점도로 표시하고, 완벽한 예측을 나타내는 대각선을 함께 그려 모델의 성능을 시각적으로 확인합니다.

# %%
plt.scatter(y_test, y_pred)
plt.plot([y_test.min(), y_test.max()],
         [y_test.min(), y_test.max()], '--', c='r')
plt.xlabel('y_test')
plt.ylabel('y_pred')
plt.title('Boston House Price Prediction ($1,000)')
plt.show()

# %% [markdown]
# ## sklearn LinearRegression 비교

# %% [markdown]
# 신경망 모델과 비교하기 위해 sklearn의 LinearRegression을 사용합니다. 선형 회귀 모델의 성능을 확인하여 신경망 모델과 비교할 수 있습니다.

# %%
from sklearn.linear_model import LinearRegression
regr = LinearRegression()

# %% [markdown]
# 데이터를 다시 분할하고 스케일링합니다. 새로운 train_test_split을 사용하여 다른 데이터 분할로 모델을 학습시킵니다.
#
# X_train, X_test, y_train, y_test = train_test_split(X, y)
#
# sc = MinMaxScaler()
# X_train = sc.fit_transform(X_train)
# X_test  = sc.transform(X_test)

# %% [markdown]
# LinearRegression 모델을 훈련 데이터로 학습시킵니다.

# %%
regr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# 학습된 LinearRegression 모델로 테스트 데이터에 대한 예측을 수행합니다.

# %%
y_pred = regr.predict(X_test)

# %% [markdown]
# LinearRegression 모델의 계수(Coefficients)와 절편(Intercept)을 확인합니다. 각 특성의 기여도를 확인할 수 있습니다.

# %% [markdown]
# LinearRegression 모델의 성능을 평가합니다. MSE와 R² 점수를 계산하여 신경망 모델과 비교합니다.

# %%
# MSE(mean squared error) 계산
print("Mean squared error: {:.2f}".format(mean_squared_error(y_test, y_pred)))

# R2 계산
print("Variance score: {:.2f}".format(r2_score(y_test, y_pred)))
# Out:
# Mean squared error: 29.89
# Variance score: 0.63

# %% [markdown]
# ## 실습
#
# ### UCI Machine Learning Repository 의 Auto MPG dataset 을 사용하여 자동차 연비 예측 Regression model 작성
#
# - auto-mpg.data - data file
#
#
# - auto-mpg.names - data 설명 file
#
#     1. mpg:           continuous
#     2. cylinders:     multi-valued discrete
#     3. displacement:  continuous (배기량)
#     4. horsepower:    continuous
#     5. weight:        continuous
#     6. acceleration:  continuous
#     7. model year:    multi-valued discrete
#     8. origin:        multi-valued discrete, 1 - USA, 2 - Europe, 3 - Japan
#     9. car name:      string (unique for each instance)
#
# Missing Attribute Values:  horsepower has 6 missing values  ==> "?" 로 들어 있으므로 read_csv 시 nan 으로 변환

# %% [markdown]
# 필요한 라이브러리를 import 합니다. Auto MPG 데이터셋을 사용하여 자동차 연비 예측 모델을 구축합니다.

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### Data load 및 Preprocessing

# %% [markdown]
# Auto MPG 데이터셋을 다운로드하고 로드합니다. horsepower 컬럼의 결측값("?")을 na_values로 지정하여 NaN으로 변환합니다.

# %%
# TensorFlow에서 제공하는 유틸리티 함수로 데이터 파일 다운로드
data_path = tf.keras.utils.get_file(
    "auto-mpg.data",
    "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data"
)

# Auto MPG 데이터셋의 각 컬럼 이름 정의
# mpg: 연비 (목표 변수)
# 나머지 컬럼: 자동차의 물리적/엔진 특성
column_names = [
    'mpg',           # 연비 (miles per gallon)
    'cylinders',     # 실린더 수
    'displacement',  # 배기량
    'horsepower',    # 마력
    'weight',        # 차량 무게
    'acceleration',  # 가속도
    'model year',    # 출시 연도
    'origin'         # 제조 국가 코드
]

# Pandas로 원본 데이터 파일 읽기
rawdata = pd.read_csv(
    data_path,                           # 다운로드된 데이터 파일 경로
    names=column_names,      # 컬럼 이름 지정
    na_values="?",                    # '?' 문자를 결측치(NaN)로 처리
    comment="\t",                      # 탭 문자로 시작하는 줄은 주석으로 간주
    sep=" ",                                # 공백을 기준으로 컬럼 구분
    skipinitialspace=True          # 연속된 공백 무시
)

# 데이터의 상위 5개 행 확인
rawdata.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    model year  origin
# 0          70       1
# 1          70       1
# 2          70       1
# 3          70       1
# 4          70       1

# %% [markdown]
# 결측값이 있는 행을 제거하고, 범주형 변수(cylinders, origin)를 원-핫 인코딩으로 변환합니다. 그 다음 타겟 변수(mpg)를 분리하고 데이터를 훈련/테스트 세트로 나눕니다.

# %%
# 결측치(NaN)가 포함된 행을 모두 제거
rawdata.dropna(inplace=True)

# 원본 데이터를 보존하기 위해 복사본 생성
data = rawdata.copy()

# 범주형 변수(cylinders, origin)를 원-핫 인코딩(one-hot encoding)으로 변환
# - 숫자이지만 범주 의미를 가지는 변수이므로 더미 변수로 처리
data = pd.get_dummies(
    data,
    columns=['cylinders', 'origin']
)

# 예측 대상 변수(mpg, 연비)를 feature 데이터에서 분리
label = data.pop('mpg')

# 전체 데이터를 학습용(train)과 테스트용(test)으로 분리
X_train, X_test, y_train, y_test = train_test_split(data.values, label.values)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((294, 13), (98, 13), (294,), (98,))

# %% [markdown]
# StandardScaler를 사용하여 특성을 표준화합니다. 평균 0, 표준편차 1로 정규화하여 모델 학습의 안정성을 높입니다.

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ### Regression Model Build
#
# ### train
#
# ### predict
#
# ### $r^2$ 계산
#
# ### 시각화
