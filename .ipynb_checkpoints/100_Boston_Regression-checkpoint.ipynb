# %% [markdown]
# # 100. Boston House Price Regression
#
# - 보스턴 주택가격 예측
#
# ### 13 개의 종속변수와 1 개의 독립변수 (주택가격 중앙값) 으로 구성
#
# #### 종속변수 (13 개)
# CRIM 자치시(town) 별 1인당 범죄율
# ZN 25,000 평방피트를 초과하는 거주지역의 비율
# INDUS 비소매상업지역이 점유하고 있는 토지의 비율
# CHAS 찰스강에 대한 더미변수(강의 경계에 위치한 경우는 1, 아니면 0)
# NOX 10ppm 당 농축 일산화질소
# RM 주택 1가구당 평균 방의 개수
# AGE 1940년 이전에 건축된 소유주택의 비율
# DIS 5개의 보스턴 직업센터까지의 접근성 지수
# RAD 방사형 도로까지의 접근성 지수
# TAX 10,000 달러 당 재산세율
# PTRATIO 자치시(town)별 학생/교사 비율
# B 1000(Bk-0.63)^2, 여기서 Bk는 자치시별 흑인의 비율을 말함
# LSTAT 모집단의 하위계층의 비율(%)
#
# #### 독립변수 (1 개)
# MEDV 본인 소유의 주택가격(중앙값) (단위: $1,000)

# %% [markdown]
# 필요한 라이브러리를 import 합니다. TensorFlow/Keras를 사용하여 신경망 모델을 구축하고, sklearn을 사용하여 데이터 전처리와 평가를 수행합니다.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np

# %% [markdown]
# Boston 주택가격 데이터셋을 로드합니다. sklearn의 load_boston이 제거되었으므로 직접 데이터를 다운로드하고 전처리합니다.

# %%
data_url = "http://lib.stat.cmu.edu/datasets/boston"

# 원본 텍스트 데이터를 읽어 DataFrame으로 변환
# sep=r"\s+"  : 하나 이상의 공백을 구분자로 사용
# skiprows=22 : 상단의 설명용 22행은 건너뜀
# header=None : 컬럼명이 없으므로 자동 인덱스 사용
raw_df = pd.read_csv(data_url, sep=r"\s+", skiprows=22, header=None)

# Boston 데이터는 한 샘플이 두 줄에 걸쳐 저장되어 있음
# 짝수 행(::2)과 홀수 행(1::2)의 데이터를 합쳐 하나의 샘플로 구성
data = np.hstack([
    raw_df.values[::2, :],      # 첫 번째 줄(특성의 앞부분)
    raw_df.values[1::2, :2]     # 두 번째 줄의 앞 2개 특성
])

# 목표 변수(target): 주택 가격(MEDV)
# 두 번째 줄의 세 번째 값에 해당
target = raw_df.values[1::2, 2]

# 각 특성(feature)의 이름 정의
feature_names = [
    'CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM',
    'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT'
]

# 특성 데이터와 컬럼명을 사용해 DataFrame 생성
df_boston = pd.DataFrame(data, columns=feature_names)

df_boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %% [markdown]
# 특성 데이터(X)와 타겟 데이터(y)를 분리합니다. X는 13개의 특성, y는 주택가격 중앙값입니다.

# %%
X = data
y = target
X.shape, y.shape
# Out:
# ((506, 13), (506,))

# %% [markdown]
# 데이터를 훈련 세트와 테스트 세트로 분할합니다. 기본적으로 75%는 훈련, 25%는 테스트 데이터로 나뉩니다.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((379, 13), (127, 13), (379,), (127,))

# %% [markdown]
# 특성 스케일링을 수행합니다. MinMaxScaler를 사용하여 모든 특성을 0과 1 사이의 값으로 정규화합니다. 신경망 모델의 학습 안정성을 높입니다.

# %%
sc = MinMaxScaler()
X_train = sc.fit_transform(X_train)
X_test  = sc.transform(X_test)

# %% [markdown]
# ### model build

# %% [markdown]
# Sequential 모델을 생성하고 레이어를 추가합니다. 입력층(13개 특성), 은닉층 2개(64, 32 뉴런), 출력층(1개 뉴런)으로 구성된 신경망을 만듭니다.

# %%
model = Sequential([
    Input(shape=(13,)),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1)
])

# %% [markdown]
# 모델을 컴파일합니다. 회귀 문제이므로 손실 함수는 mean_squared_error를 사용하고, 옵티마이저는 adam을 사용합니다.

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %% [markdown]
# 모델의 구조를 요약하여 출력합니다. 각 레이어의 파라미터 수와 모델의 전체 구조를 확인할 수 있습니다.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 64)                  │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,009 (11.75 KB)
#  Trainable params: 3,009 (11.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# - epoch 수와 batchz_size 변경하며 test

# %% [markdown]
# 모델을 학습시킵니다. batch_size=32, epochs=100 으로 설정하고, validation_data로 테스트 데이터를 사용하여 검증 손실을 모니터링합니다.

# %%
history = model.fit(X_train, y_train, batch_size=32,
                    epochs=100, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 577.8843 - val_loss: 581.9145
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 552.1961 - val_loss: 551.5737
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 517.6506 - val_loss: 510.2481
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 471.3137 - val_loss: 453.6893
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 408.5867 - val_loss: 380.0118
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 330.6441 - val_loss: 294.0783
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 249.6686 - val_loss: 208.1461
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 176.9023 - val_loss: 147.0720
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 139.0625 - val_loss: 118.5850
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 125.4155 - val_loss: 106.9163
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 116.0382 - val_loss: 98.2334
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 106.7427 - val_loss: 90.0950
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 98.6627 - val_loss: 83.1492
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 91.3143 - val_loss: 75.6283
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 83.8357 - val_loss: 69.2530
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 77.6832 - val_loss: 63.4525
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 71.9741 - val_loss: 58.5677
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 67.3199 - val_loss: 54.4906
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 63.4612 - val_loss: 51.0346
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 60.0008 - val_loss: 48.5153
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 57.6713 - val_loss: 46.3343
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 55.2982 - val_loss: 44.6555
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 53.3732 - val_loss: 43.2364
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 51.8935 - val_loss: 41.8558
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 50.3148 - val_loss: 40.6658
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 48.9087 - val_loss: 39.5457
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 47.4137 - val_loss: 38.3784
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 46.3049 - val_loss: 37.3432
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 44.5902 - val_loss: 36.3579
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 43.3770 - val_loss: 35.4198
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 41.9818 - val_loss: 34.1816
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 40.6671 - val_loss: 33.3143
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 39.3790 - val_loss: 32.3499
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 38.1742 - val_loss: 31.4813
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 36.9961 - val_loss: 30.4405
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 35.7763 - val_loss: 29.6312
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 34.7819 - val_loss: 28.9448
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 33.7499 - val_loss: 27.9480
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 32.5428 - val_loss: 27.6695
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 31.6666 - val_loss: 26.6155
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 30.6721 - val_loss: 26.0767
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 29.7678 - val_loss: 25.3113
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.9949 - val_loss: 24.8468
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.1919 - val_loss: 24.3562
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 27.9407 - val_loss: 24.1160
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 26.9652 - val_loss: 23.2800
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.9668 - val_loss: 23.3027
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.5667 - val_loss: 22.7818
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.0409 - val_loss: 22.4828
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 24.6154 - val_loss: 22.0355
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.9696 - val_loss: 21.8574
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.5060 - val_loss: 21.6221
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.4831 - val_loss: 21.3018
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.9045 - val_loss: 21.9226
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.6150 - val_loss: 20.9035
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.2479 - val_loss: 21.2165
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 22.0080 - val_loss: 20.6876
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.4849 - val_loss: 20.9785
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.4299 - val_loss: 20.7166
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.2561 - val_loss: 20.5201
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.8939 - val_loss: 20.6311
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.7135 - val_loss: 20.3057
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.6127 - val_loss: 20.1729
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.2824 - val_loss: 20.5681
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.1627 - val_loss: 20.2629
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.1003 - val_loss: 20.1105
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.8742 - val_loss: 20.5705
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19.8951 - val_loss: 19.9594
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.5077 - val_loss: 20.3065
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.4759 - val_loss: 20.2235
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.3896 - val_loss: 20.2252
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.1748 - val_loss: 19.9613
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.0919 - val_loss: 20.1133
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.1612 - val_loss: 20.0244
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.1679 - val_loss: 19.9976
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.7457 - val_loss: 20.0160
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 18.7698 - val_loss: 19.8955
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.5214 - val_loss: 20.3589
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 18.4947 - val_loss: 19.8277
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.4362 - val_loss: 20.0009
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 18.4066 - val_loss: 19.9904
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.3290 - val_loss: 20.0217
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.0976 - val_loss: 19.9331
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.0490 - val_loss: 19.8686
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 18.0104 - val_loss: 20.0080
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.9754 - val_loss: 19.9912
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.7540 - val_loss: 19.9913
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.5608 - val_loss: 19.7141
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.6590 - val_loss: 19.8422
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.4084 - val_loss: 19.7486
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.4508 - val_loss: 19.8888
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.4175 - val_loss: 19.7769
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.1529 - val_loss: 19.8744
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.0501 - val_loss: 19.6785
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.0163 - val_loss: 19.7408
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.0469 - val_loss: 20.0435
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.8589 - val_loss: 19.5347
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.8042 - val_loss: 20.0320
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.6323 - val_loss: 19.6080
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.5955 - val_loss: 19.8706

# %% [markdown]
# 학습된 모델을 테스트 데이터로 평가합니다. 테스트 손실 값을 확인할 수 있습니다.

# %%
model.evaluate(X_test, y_test, verbose=0)
# Out:
# 19.87059783935547

# %% [markdown]
# 학습된 모델을 사용하여 테스트 데이터에 대한 예측을 수행합니다.

# %%
y_pred = model.predict(X_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %% [markdown]
# 모델의 성능을 평가합니다. Mean Squared Error(MSE)와 R² 점수를 계산하여 모델의 예측 정확도를 확인합니다.

# %%
from sklearn.metrics import mean_squared_error, r2_score

print(mean_squared_error(y_test, y_pred))
print(r2_score(y_test, y_pred))
# Out:
# 19.87059640631521
# 0.7412170503112264

# %% [markdown]
# 예측 결과를 시각화합니다. 실제값(y_test)과 예측값(y_pred)을 산점도로 표시하고, 완벽한 예측을 나타내는 대각선을 함께 그려 모델의 성능을 시각적으로 확인합니다.

# %%
plt.scatter(y_test, y_pred)
plt.plot([y_test.min(), y_test.max()],
         [y_test.min(), y_test.max()], '--', c='r')
plt.xlabel('y_test')
plt.ylabel('y_pred')
plt.title('Boston House Price Prediction ($1,000)')
plt.show()

# %% [markdown]
# ## 실습
#
# ### UCI Machine Learning Repository 의 Auto MPG dataset 을 사용하여 자동차 연비 예측 Regression model 작성
#
# - auto-mpg.data - data file
#
#
# - auto-mpg.names - data 설명 file
#
#     1. mpg:           continuous
#     2. cylinders:     multi-valued discrete
#     3. displacement:  continuous (배기량)
#     4. horsepower:    continuous
#     5. weight:        continuous
#     6. acceleration:  continuous
#     7. model year:    multi-valued discrete
#     8. origin:        multi-valued discrete, 1 - USA, 2 - Europe, 3 - Japan
#     9. car name:      string (unique for each instance)
#
# Missing Attribute Values:  horsepower has 6 missing values  ==> "?" 로 들어 있으므로 read_csv 시 nan 으로 변환

# %% [markdown]
# 필요한 라이브러리를 import 합니다. Auto MPG 데이터셋을 사용하여 자동차 연비 예측 모델을 구축합니다.

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### Data load 및 Preprocessing

# %% [markdown]
# Auto MPG 데이터셋을 다운로드하고 로드합니다. horsepower 컬럼의 결측값("?")을 na_values로 지정하여 NaN으로 변환합니다.

# %%
# TensorFlow에서 제공하는 유틸리티 함수로 데이터 파일 다운로드
data_path = tf.keras.utils.get_file(
    "auto-mpg.data",
    "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data"
)

# Auto MPG 데이터셋의 각 컬럼 이름 정의
# mpg: 연비 (목표 변수)
# 나머지 컬럼: 자동차의 물리적/엔진 특성
column_names = [
    'mpg',           # 연비 (miles per gallon)
    'cylinders',     # 실린더 수
    'displacement',  # 배기량
    'horsepower',    # 마력
    'weight',        # 차량 무게
    'acceleration',  # 가속도
    'model year',    # 출시 연도
    'origin'         # 제조 국가 코드
]

# Pandas로 원본 데이터 파일 읽기
rawdata = pd.read_csv(
    data_path,                           # 다운로드된 데이터 파일 경로
    names=column_names,      # 컬럼 이름 지정
    na_values="?",                    # '?' 문자를 결측치(NaN)로 처리
    comment="\t",                      # 탭 문자로 시작하는 줄은 주석으로 간주
    sep=" ",                                # 공백을 기준으로 컬럼 구분
    skipinitialspace=True          # 연속된 공백 무시
)

# 데이터의 상위 5개 행 확인
rawdata.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    model year  origin
# 0          70       1
# 1          70       1
# 2          70       1
# 3          70       1
# 4          70       1

# %% [markdown]
# 결측값이 있는 행을 제거하고, 범주형 변수(cylinders, origin)를 원-핫 인코딩으로 변환합니다. 그 다음 타겟 변수(mpg)를 분리하고 데이터를 훈련/테스트 세트로 나눕니다.

# %%
# 결측치(NaN)가 포함된 행을 모두 제거
rawdata.dropna(inplace=True)

# 원본 데이터를 보존하기 위해 복사본 생성
data = rawdata.copy()

# 범주형 변수(cylinders, origin)를 원-핫 인코딩(one-hot encoding)으로 변환
# - 숫자이지만 범주 의미를 가지는 변수이므로 더미 변수로 처리
data = pd.get_dummies(
    data,
    columns=['cylinders', 'origin']
)

# 예측 대상 변수(mpg, 연비)를 feature 데이터에서 분리
label = data.pop('mpg')

# 전체 데이터를 학습용(train)과 테스트용(test)으로 분리
X_train, X_test, y_train, y_test = train_test_split(data.values, label.values)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((294, 13), (98, 13), (294,), (98,))

# %% [markdown]
# StandardScaler를 사용하여 특성을 표준화합니다. 평균 0, 표준편차 1로 정규화하여 모델 학습의 안정성을 높입니다.

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ### Regression Model Build
#
# ### train
#
# ### predict
#
# ### $r^2$ 계산
#
# ### 시각화
